# %% [markdown]
# # Evidencia Final: Herramientas Computacionales
# ## Miembros del equipo:
# - Vera Sofía Acevedo Gómez  A01747156
# - Yael Michel García López  A01750911

# %%
# Importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Leer el archivo
df = pd.read_csv("unis.csv")

# %% [markdown]
# ## Exploración Inicial

# %%
# Obtener información general
df.info()

# 2341 entidades
# 12 columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1697 entries, 0 to 1696
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   University Rank              1697 non-null   int64
#  1   Name of University           1697 non-null   object
#  2   Location                     1697 non-null   object
#  3   No of student                1697 non-null   object
#  4   No of student per staff      1697 non-null   float64
#  5   International Student        1697 non-null   object
#  6   Female:Male Ratio            1621 non-null   object
#  7   OverAll Score                1697 non-null   object
#  8   Teaching Score               1697 non-null   float64
#  9   Research Score               1697 non-null   float64
#  10  Citations Score              1697 non-null   float64
#  11  Industry Income Score        1697 non-null   float64
#  12  International Outlook Score  1697 non-null   float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 185.6+ KB

# %%
df.head(18)

# No of student object
# International Student object
# OverAll Score object
# Female y Male convertirlos a object y dividirlos
# Out:
#    University Rank                     Name of University        Location  \
# 0                1                   University of Oxford  United Kingdom
# 1                2                     Harvard University   United States
# 2                3                University of Cambridge  United Kingdom
# 3                3                    Stanford University   United States
# 4                5  Massachusetts Institute of Technology   United States
# 5                6     California Institute of Technology   United States
# 6                7                   Princeton University   United States
# 7                8     University of California, Berkeley   United States
# 8                9                        Yale University   United States
# 9               10                Imperial College London  United Kingdom
# 10              11                    Columbia University   United States
# 11              11                             ETH Zurich     Switzerland
# 12              13              The University of Chicago   United States
# 13              14             University of Pennsylvania   United States
# 14              15               Johns Hopkins University   United States
# 15              16                    Tsinghua University           China
# 16              17                      Peking University           China
# 17              18                  University of Toronto          Canada
#
#    No of student  No of student per staff International Student  \
# 0         20,965                     10.6                   42%
# 1         21,887                      9.6                   25%
# 2         20,185                     11.3                   39%
# 3         16,164                      7.1                   24%
# 4         11,415                      8.2                   33%
# 5          2,237                      6.2                   34%
# 6          8,279                      8.0                   23%
# 7         40,921                     18.4                   24%
# 8         13,482                      5.9                   21%
# 9         18,545                     11.2                   61%
# 10        21,781                      4.5                   38%
# 11        21,665                     14.8                   41%
# 12        15,366                      6.0                   36%
# 13        21,453                      6.3                   23%
# 14        17,584                      4.7                   29%
# 15        38,324                     11.6                   10%
# 16        31,994                     10.3                   19%
# 17        77,468                     25.8                   26%
#
#    Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 0            48 : 52          96.4            92.3            99.7
# 1            50 : 50          95.2            94.8            99.0
# 2            47 : 53          94.8            90.9            99.5
# 3            46 : 54          94.8            94.2            96.7
# 4            40 : 60          94.2            90.7            93.6
# 5            37 : 63          94.1            90.9            97.0
# 6            46 : 54          92.4            87.6            95.9
# 7            52 : 48          92.1            86.4            95.8
# 8            52 : 48          91.4            92.6            92.7
# 9            40 : 60          90.4            82.8            90.8
# 10               NaN          89.4            89.4            87.7
# 11           33 : 67          89.4            82.6            95.4
# 12           47 : 53          88.9            86.5            88.8
# 13           53 : 47          88.8            86.0            88.8
# 14           53 : 47          88.3            79.4            91.5
# 15               NaN          88.2            90.1            97.4
# 16               NaN          88.1            92.5            96.7
# 17           56 : 44          87.4            77.3            93.3
#
#     Citations Score  Industry Income Score  International Outlook Score
# 0              99.0                   74.9                         96.2
# 1              99.3                   49.5                         80.5
# 2              97.0                   54.2                         95.8
# 3              99.8                   65.0                         79.8
# 4              99.8                   90.9                         89.3
# 5              97.3                   89.8                         83.6
# 6              99.1                   66.0                         80.3
# 7              99.0                   76.8                         78.4
# 8              97.0                   55.0                         70.9
# 9              98.3                   59.8                         97.5
# 10             97.1                   44.8                         79.9
# 11             90.7                   59.1                         97.7
# 12             97.7                   56.2                         74.2
# 13             97.0                   75.8                         71.5
# 14             97.0                   89.5                         75.3
# 15             88.0                  100.0                         40.3
# 16             80.4                   91.8                         65.0
# 17             92.8                   65.5                         89.7

# %%
df.isna().sum()
# Out:
# University Rank                 0
# Name of University              0
# Location                        0
# No of student                   0
# No of student per staff         0
# International Student           0
# Female:Male Ratio              76
# OverAll Score                   0
# Teaching Score                  0
# Research Score                  0
# Citations Score                 0
# Industry Income Score           0
# International Outlook Score     0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [University Rank, Name of University, Location, No of student, No of student per staff, International Student, Female:Male Ratio, OverAll Score, Teaching Score, Research Score, Citations Score, Industry Income Score, International Outlook Score]
# Index: []

# %%
# Eliminamos Duplicados
df = df.drop_duplicates()

# %%
df["Name of University"].describe()
# No hay nombres de universidades repetidos
# Out:
# count                                    2233
# unique                                   2233
# top       Xi’an Jiaotong-Liverpool University
# freq                                        1
# Name: Name of University, dtype: object

# %%
#df['University Rank'] == "-"

#Recuento de valores de Rank "-"
count = (df['University Rank'] == "-").sum()
print(count)
# Out:
# 0

# %%
df = df.drop(df[df['University Rank'] == "-"].index)
# Eliminamos los que no tengan Rank

# %%
count = (df['University Rank'] == "Reporter").sum()
print(count)
# Out:
# 512

# %%
null_location_indices = df[df['No of student per staff'].isnull()].index
print(null_location_indices)
# Out:
# Index([1865], dtype='int64')

# %%
# Llenar la Location con "Unknown"
df['Location'].fillna("Unknown", inplace=True)

# %%
df['University Rank'] = range(1, len(df) + 1)

# %%
df.tail()
# Out:
#       University Rank                     Name of University        Location  \
# 2204             2205            Yogyakarta State University       Indonesia
# 2205             2206                York St John University  United Kingdom
# 2206             2207    Yusuf Maitama Sule University, Kano         Nigeria
# 2207             2208  Zhytomyr Polytechnic State University         Ukraine
# 2208             2209                    Ziauddin University        Pakistan
#
#      No of student  No of student per staff International Student  \
# 2204        23,685                     18.5                    1%
# 2205         6,315                     18.6                   12%
# 2206        12,880                     33.0                    0%
# 2207         3,869                     15.4                    1%
# 2208         4,906                      8.8                    1%
#
#      Female:Male Ratio OverAll Score  Teaching Score  Research Score  \
# 2204           59 : 41           NaN             NaN             NaN
# 2205           65 : 35           NaN             NaN             NaN
# 2206           48 : 52           NaN             NaN             NaN
# 2207           34 : 66           NaN             NaN             NaN
# 2208           63 : 37           NaN             NaN             NaN
#
#       Citations Score  Industry Income Score  International Outlook Score
# 2204              NaN                    NaN                          NaN
# 2205              NaN                    NaN                          NaN
# 2206              NaN                    NaN                          NaN
# 2207              NaN                    NaN                          NaN
# 2208              NaN                    NaN                          NaN

# %%
df.loc[1865]
# Out:
# University Rank                                 1866
# Name of University             Fundação Oswaldo Cruz
# Location                                      Brazil
# No of student                                  3,699
# No of student per staff                          NaN
# International Student                              %
# Female:Male Ratio                                NaN
# OverAll Score                                    NaN
# Teaching Score                                   NaN
# Research Score                                   NaN
# Citations Score                                  NaN
# Industry Income Score                            NaN
# International Outlook Score                      NaN
# Name: 1865, dtype: object

# %%
df = df.dropna(subset=['OverAll Score'])
